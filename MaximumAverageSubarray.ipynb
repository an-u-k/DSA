# %% [markdown]
# 643. Maximum Average Subarray I
#
# You are given an integer array nums consisting of n elements, and an integer k.
# Find a contiguous subarray whose length is equal to k that has the maximum average value and return this value. Any answer with a calculation error less than 10-5 will be accepted.

# %%
from typing import List

# %%
class Solution:
    def findMaxAverage(self, nums: List[int], k: int) -> float:
        i =0
        maximum=10**-5
        while(i+k < len(nums)+1):
            
            sum =0.00000
            for j in range (i,i+k):
                sum+= nums[j]
                   
            maximum = max(maximum,sum/k)
        
            i+=1
        return maximum

# %% [markdown]
# I use brute force approach initially the time limit exceeds the time com[plexity here is 0(n2) so i need to reduce that to O(n) foir that i use sliding window approach

# %%
solution = Solution()
result= solution.findMaxAverage([5],1)      
print(result)
# Out:
# 1.25
# 1.25

# %%
class Solution:
    def findMaxAverage(self, nums: List[int], k: int) -> float:
        max_sum = float('-inf')
        for i in range (len(nums)-k+1):
            current_sum = sum(nums[i:i+k])  /k
            max_sum = max(current_sum, max_sum)

        return max_sum

# %%
class Solution:
    def findMaxAverage(self, nums: List[int], k: int) -> float:
        
        current_sum = sum(nums[:k])
        max_sum = current_sum
        for i in range (k,len(nums)):
            current_sum += nums[i]-nums[i-k]
            max_sum = max(current_sum, max_sum)
        return max_sum/k
